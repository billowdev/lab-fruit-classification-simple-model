# %% [markdown]
# # Introduction

# %% [markdown]
# Hi I'm lacakp : )
# github: https://github.com/lacakp
#
# - Classification Apple Banana and Tomato
#
# - Transfer Learning Using Keras -- MobileNetv2 :
# Efficient Convolutional Neural Networks for Mobile Vision Applications
#
# - Transfer Learning คือ เทคนิคที่ช่วยลดเวลาการเทรนโมเดล Deep Learning ด้วยการนำบางส่วนของโมเดลที่เทรนเรียบร้อยแล้ว กับงานที่ใกล้เคียงกัน มาใช้เป็นส่วนหนึ่งของโมเดลใหม่
#
# - MobileNet คืออะไร : Keng Surapong 2020-01-12
# - https://www.bualabs.com/archives/3439/tensorflow-js-tutorial-build-image-classification-javascript-mobilenet-pretrained-model-tfjs-ep-7/
# - Transfer Learning คืออะไร : Keng Surapong 2020-01-14
# - https://www.bualabs.com/archives/3493/what-is-transfer-learning-build-headless-mobilenet-model-transfer-learning-machine-learning-mobilenet-json-retrain-webcam-tensorflow-js-tfjs-ep-10/
# - Neural Network Programming : โดย ชิตพงษ์ กิตตินราดร | มกราคม 2563
# - https://guopai.github.io/ml-blog15.html
# - 3 วิธีในการสร้างโมเดล Machine Learning ด้วย Keras และ TensorFlow 2.0 : ICHI.PRO
# - https://ichi.pro/th/3-withi-ni-kar-srang-model-machine-learning-dwy-keras-laea-tensorflow-2-0-244131078796499

# %% [markdown]
# #Pipeline
# 1. Data Acquisition
# 2. Training The Model
# 3. Evaluation
# 4. Prediction
# 5. Deploy Model

# %% [markdown]
# ## Data Acquisition

# %% [markdown]
# ### get data

# %% [markdown]
# - Fruits 360 : __https://www.kaggle.com/moltean/fruits__
#
# - A dataset with 90380 images of 131 fruits and vegetables
#
# - <img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-sa/4.0/88x31.png" scale="0">
#
# - This work is licensed under a
# <a rel="license" href="https://creativecommons.org/licenses/by-sa/4.0/">Creative Commons Attribution-ShareAlike 4.0 International License</a>

# %% [markdown]
# __ทำการดาวน์โหลดข้อมูล Dataset และ ทำการ unzip ไฟล์ abt-fruit.zip ที่ดาวน์โหลดมา__

# %%
# !wget https://codeload.github.com/lacakp/fruit-ds/zip/refs/tags/abt-v1.2
# !unzip "/content/abt-v1.2"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_147_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_148_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_149_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_150_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_151_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_152_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_153_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_154_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_155_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_156_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_157_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_158_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_159_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_160_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_161_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_162_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_163_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_164_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_165_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_166_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_167_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_168_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_169_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_170_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_171_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_172_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_173_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_174_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_175_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_176_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_177_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_178_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_179_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_17_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_180_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_181_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_182_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_183_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_184_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_185_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_186_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_187_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_188_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_189_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_190_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_191_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_192_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_193_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_194_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_195_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_196_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_197_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_198_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_199_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_1_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_200_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_201_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_202_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_203_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_204_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_205_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_206_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_208_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_209_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_20_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_210_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_211_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_212_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_214_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_217_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_218_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_219_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_21_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_220_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_221_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_222_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_224_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_225_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_22_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_247_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_248_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_249_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_250_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_251_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_252_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_253_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_254_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_255_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_256_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_257_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_258_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_259_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_260_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_261_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_262_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_263_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_264_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_265_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_266_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_267_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_268_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_269_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_26_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_270_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_271_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_272_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_273_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_274_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_275_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_276_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_277_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_278_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_279_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_27_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_280_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_281_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_282_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_283_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_284_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_285_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_286_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_287_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_288_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_289_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_290_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_291_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_292_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_293_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_294_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_295_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_296_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_297_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_298_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_299_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_2_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_300_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_301_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_302_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_303_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_304_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_305_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_306_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_307_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_308_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_309_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_310_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_311_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_312_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_313_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_314_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_315_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_318_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_322_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_323_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_324_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_3_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_4_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_53_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_55_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_58_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_5_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_62_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_64_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_65_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_6_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_74_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_75_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_76_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_77_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_78_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_79_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_7_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_80_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_81_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_82_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_83_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_84_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_85_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_86_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_87_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_88_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_89_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_8_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_90_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_91_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_92_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_93_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_94_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_95_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_96_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_97_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_98_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_99_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/Banana/r_9_100.jpg
#    creating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (1).jpeg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (1).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (1).png
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (10).JPG
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (10).png
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (11).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (12).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (13).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (14).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (15).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (16).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (17).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (18).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (19).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (2).jpeg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (2).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (2).png
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (20).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (21).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (22).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (23).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (24).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (25).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (26).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (27).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (28).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (29).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (3).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (3).png
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (30).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (31).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (32).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (33).jpg
#  extracting: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (34).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (35).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (36).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (37).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (38).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (39).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (4).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (4).png
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (40).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (41).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (42).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (43).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (44).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (45).jpg
#  extracting: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (46).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (47).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (48).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (49).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (5).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (5).png
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (50).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (51).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (52).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (53).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (54).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (55).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (56).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (6).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (6).png
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (7).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (7).png
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (8).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (8).png
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (9).jpg
#   inflating: fruit-ds-abt-v1.2/train/Banana/kritikseth-banana/kritikseth-banana (9).png
#    creating: fruit-ds-abt-v1.2/train/Tomato/
#    creating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/0_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/100_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/101_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/102_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/103_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/104_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/105_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/106_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/107_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/108_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/109_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/110_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/111_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/112_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/113_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/114_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/115_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/116_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/117_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/118_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/119_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/120_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/121_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/122_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/123_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/124_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/125_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/126_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/127_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/128_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/129_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/12_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/130_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/131_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/132_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/133_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/134_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/135_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/136_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/137_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/138_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/139_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/13_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/140_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/141_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/142_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/143_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/144_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/145_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/146_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/147_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/148_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/149_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/14_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/150_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/151_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/152_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/153_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/154_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/155_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/156_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/157_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/158_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/159_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/15_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/160_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/161_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/162_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/163_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/164_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/165_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/166_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/167_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/168_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/169_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/16_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/170_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/171_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/172_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/173_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/174_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/175_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/176_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/177_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/178_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/179_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/17_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/18_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/19_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/1_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/20_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/218_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/219_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/21_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/220_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/221_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/222_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/223_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/224_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/225_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/226_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/227_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/228_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/229_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/22_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/230_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/231_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/232_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/233_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/234_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/235_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/236_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/237_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/238_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/239_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/23_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/240_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/241_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/242_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/243_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/244_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/245_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/246_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/247_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/248_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/249_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/250_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/251_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/252_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/253_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/254_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/255_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/256_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/257_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/258_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/259_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/260_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/261_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/262_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/263_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/264_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/265_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/266_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/267_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/268_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/269_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/270_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/271_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/272_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/273_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/274_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/275_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/276_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/277_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/278_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/279_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/280_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/281_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/282_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/283_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/284_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/285_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/286_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/287_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/288_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/289_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/290_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/291_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/292_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/293_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/294_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/295_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/296_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/297_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/298_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/299_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/29_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/2_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/300_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/301_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/302_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/303_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/305_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/306_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/307_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/308_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/309_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/30_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/310_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/311_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/312_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/313_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/314_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/315_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/316_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/317_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/323_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/325_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/33_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/3_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/45_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/46_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/4_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/58_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/59_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/5_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/63_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/64_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/65_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/66_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/67_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/68_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/69_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/6_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/70_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/71_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/72_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/73_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/74_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/75_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/76_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/77_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/78_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/79_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/7_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/80_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/81_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/82_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/83_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/84_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/85_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/86_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/87_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/88_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/89_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/8_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/90_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/91_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/92_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/93_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/94_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/95_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/96_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/97_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/98_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/99_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_0_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_100_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_101_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_102_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_103_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_104_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_105_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_106_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_107_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_108_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_109_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_10_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_110_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_111_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_112_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_113_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_114_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_115_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_116_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_117_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_118_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_119_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_11_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_120_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_121_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_122_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_123_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_124_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_125_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_126_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_127_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_128_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_129_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_130_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_131_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_132_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_133_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_134_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_135_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_136_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_137_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_138_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_139_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_13_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_140_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_141_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_142_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_143_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_144_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_145_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_146_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_147_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_148_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_149_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_14_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_150_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_151_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_152_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_153_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_154_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_155_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_156_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_157_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_158_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_159_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_15_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_160_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_162_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_163_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_164_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_168_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_169_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_16_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_170_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_171_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_172_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_173_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_174_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_175_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_176_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_177_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_178_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_179_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_17_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_180_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_181_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_182_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_183_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_184_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_185_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_186_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_187_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_188_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_189_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_18_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_190_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_191_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_192_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_193_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_194_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_195_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_196_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_197_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_198_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_199_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_19_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_1_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_200_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_201_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_202_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_203_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_204_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_205_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_206_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_207_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_20_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_210_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_211_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_212_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_213_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_214_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_215_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_217_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_219_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_21_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_222_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_22_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_23_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_24_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_25_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_26_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_27_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_286_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_287_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_288_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_289_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_28_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_290_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_291_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_292_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_293_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_294_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_296_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_297_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_298_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_299_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_29_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_2_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_300_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_301_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_302_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_303_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_304_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_305_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_306_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_307_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_308_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_309_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_30_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_310_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_311_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_312_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_313_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_314_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_315_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_316_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_317_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_318_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_319_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_31_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_320_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_321_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_322_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_323_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato 1/r2_324_100.jpg
# ...
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_189_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_18_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_190_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_191_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_192_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_193_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_194_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_195_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_196_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_197_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_198_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_199_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_19_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_1_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_200_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_201_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_202_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_203_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_20_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_21_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_22_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_23_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_24_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_25_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_26_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_27_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_28_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_29_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_2_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_30_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_31_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_32_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_33_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_34_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_35_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_36_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_37_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_38_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_39_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_3_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_40_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_41_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_42_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_43_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_44_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_45_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_46_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_47_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_48_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_49_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_50_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_51_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_52_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_53_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_54_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_55_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_56_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_57_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_58_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_59_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_60_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_61_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_62_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_63_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_64_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_65_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_66_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_67_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_68_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_69_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_6_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_70_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_71_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_72_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_73_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_74_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_75_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_76_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_77_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_78_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_79_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_7_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_80_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_81_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_82_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_83_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_84_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_85_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_86_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_87_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_88_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_89_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_8_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_90_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_91_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_92_100.jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/Tomato Yellow/r_9_100.jpg
#    creating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/
#  extracting: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (1).jpeg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (1).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (1).png
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (10).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (11).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (12).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (13).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (14).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (15).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (16).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (17).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (18).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (19).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (2).jpeg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (2).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (2).png
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (20).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (21).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (22).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (23).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (24).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (25).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (26).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (27).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (28).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (29).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (3).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (3).png
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (30).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (31).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (32).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (33).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (34).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (35).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (36).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (37).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (38).jpg
#  extracting: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (39).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (4).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (4).png
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (40).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (41).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (42).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (43).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (44).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (45).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (46).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (47).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (48).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (49).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (5).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (5).png
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (50).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (51).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (52).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (53).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (54).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (55).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (56).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (57).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (58).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (59).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (6).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (6).png
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (60).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (61).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (62).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (63).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (64).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (65).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (66).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (67).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (68).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (69).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (7).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (7).png
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (70).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (71).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (72).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (73).jpg
#  extracting: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (74).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (75).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (76).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (77).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (78).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (79).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (8).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (80).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (81).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (82).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (83).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (84).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (85).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (86).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (87).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (88).jpg
#   inflating: fruit-ds-abt-v1.2/train/Tomato/kritikseth-tomato/kritikseth-tomato (9).jpg

# %%
# ย้ายไฟล์
# !mv -v "/content/fruit-ds-abt-v1.2/test" "/content/"
# !mv -v "/content/fruit-ds-abt-v1.2/train" "/content/"
# Out:
# renamed '/content/fruit-ds-abt-v1.2/test' -> '/content/test'
# renamed '/content/fruit-ds-abt-v1.2/train' -> '/content/train'

# %%
import shutil
try:
  # !rm -rf /content/fruit-ds-abt-v1.2
  # !rm -rf /content/abt-v1.2
except:
  pass

# %% [markdown]
# ### Check data

# %%
import os
import cv2 as cv 
from google.colab.patches import cv2_imshow
import random

# %%
# !ls '/content/train'
# Out:
# Apple  Banana  Tomato

# %%
print("โฟลเดอร์ทั้งหมดใน โฟลเดอร์ Apple")
# !ls '/content/train/Apple'
print("\nโฟลเดอร์ทั้งหมดใน โฟลเดอร์ Banana")
# !ls '/content/train/Banana'
print("\nโฟลเดอร์ทั้งหมดใน โฟลเดอร์ Tomato")
# !ls '/content/train/Tomato'
# Out:
# โฟลเดอร์ทั้งหมดใน โฟลเดอร์ Apple
# 'Apple Braeburn'      'Apple Red 1'	     'Apple Red Yellow 1'
# 'Apple Crimson Snow'  'Apple Red 2'	     'Apple Red Yellow 2'
# 'Apple Granny Smith'  'Apple Red 3'	      kritikseth-apple
# 'Apple Pink Lady'     'Apple Red Delicious'
#
# โฟลเดอร์ทั้งหมดใน โฟลเดอร์ Banana
#  Banana  'Banana Lady Finger'  'Banana Red'   kritikseth-banana
#
# โฟลเดอร์ทั้งหมดใน โฟลเดอร์ Tomato
#  kritikseth-tomato  'Tomato 3'		 'Tomato Heart'
# 'Tomato 1'	    'Tomato 4'		 'Tomato Maroon'
# 'Tomato 2'	    'Tomato Cherry Red'  'Tomato Yellow'

# %%
# ฟังก์ชันสำหรับโหลดภาพเข้ามา
def load_images_from_folder(folder):
    images = [] # สร้าง list สำหรับเก็บภาพ 
    for filename in os.listdir(folder): # ลูปดูภาพใน folder 
        img = cv.imread(os.path.join(folder,filename))  # ทำการอ่านภาพจาก ชื่อภาพ โดย cv.imread เก็บไว้ img
        if img is not None: # เช็คดูว่าถ้าไม่ได้เป็นค่าว่าง 
            images.append(img) # ให้เก็บไว้ใน list images
    return images # คืนค่าเป็น list Images

# %%
apple_class_path = '/content/train/Apple/'      # path Apple In Folder train
banana_class_path = '/content/train/Banana/'    # path Banana In Folder train
tomato_class_path = '/content/train/Tomato/'    # path Tomato In Folder train

apple_folder = os.listdir(apple_class_path)     # list directory in train/apple
banana_folder = os.listdir(banana_class_path)   # list directory in train/banana
tomato_folder = os.listdir(tomato_class_path)   # list directory in train/Tomato

# initial for count imagee
apple_count, banana_count, tomato_count = 0, 0, 0  

# initial for keep all image after use load_image_from_folder function
apple_all_image, banana_all_image, tomato_all_image = [], [], [] 



import numpy as np
import matplotlib.pyplot as plt

# Function Check_image
def check_image(var_count, var_all_image, var_fruit_folder, var_class_path):
  """

  check_image function for check count image in dataset then show three random image
  ------------
  var_count : for count for each fruit image
  var_all_image : for keep all array of image
  var_fruit_folder : is list of fruit folder
  var_class_path : is variable path folder image


  """
  for folder in var_fruit_folder:
    count_image = load_images_from_folder(var_class_path + folder)
    var_all_image += load_images_from_folder(var_class_path + folder)
    var_count += len(count_image)
    print("ภาพในโฟลเดอร์", folder , "\t\tมีภาพอยู่", len(count_image))

  print("----------------\nมีภาพ", var_class_path[15:], "ทั้งหมด", var_count,   "ภาพ")
  var_ran = var_all_image
  for i in range(3):   
    ran = random.randint(1, var_count)
    cv2_imshow(var_ran[ran])

  return var_all_image

# %%
apple_img = check_image(apple_count, apple_all_image, apple_folder, apple_class_path)
banana_img = check_image(banana_count, banana_all_image, banana_folder, banana_class_path)
tomato_img = check_image(tomato_count, tomato_all_image, tomato_folder, tomato_class_path)
# Out:
# ภาพในโฟลเดอร์ Apple Crimson Snow 		มีภาพอยู่ 444
# ภาพในโฟลเดอร์ Apple Braeburn 		มีภาพอยู่ 492
# ภาพในโฟลเดอร์ Apple Red Yellow 2 		มีภาพอยู่ 672
# ภาพในโฟลเดอร์ Apple Red 3 		มีภาพอยู่ 429
# ภาพในโฟลเดอร์ Apple Red 2 		มีภาพอยู่ 492
# ภาพในโฟลเดอร์ Apple Red 1 		มีภาพอยู่ 492
# ภาพในโฟลเดอร์ Apple Pink Lady 		มีภาพอยู่ 456
# ภาพในโฟลเดอร์ Apple Red Delicious 		มีภาพอยู่ 490
# ภาพในโฟลเดอร์ Apple Granny Smith 		มีภาพอยู่ 492
# ภาพในโฟลเดอร์ kritikseth-apple 		มีภาพอยู่ 44
# ภาพในโฟลเดอร์ Apple Red Yellow 1 		มีภาพอยู่ 492
# ----------------
# มีภาพ Apple/ ทั้งหมด 4995 ภาพ
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FF5EA987C50>
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FF5EA987E10>
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FF5EAC08850>
# ภาพในโฟลเดอร์ Banana 		มีภาพอยู่ 490
# ภาพในโฟลเดอร์ kritikseth-banana 		มีภาพอยู่ 68
# ภาพในโฟลเดอร์ Banana Lady Finger 		มีภาพอยู่ 450
# ภาพในโฟลเดอร์ Banana Red 		มีภาพอยู่ 490
# ----------------
# มีภาพ Banana/ ทั้งหมด 1498 ภาพ
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FF5EA912E50>
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FF5EA912250>
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FF5EA944F50>
# ภาพในโฟลเดอร์ Tomato 4 		มีภาพอยู่ 479
# ภาพในโฟลเดอร์ Tomato Heart 		มีภาพอยู่ 684
# ภาพในโฟลเดอร์ kritikseth-tomato 		มีภาพอยู่ 97
# ภาพในโฟลเดอร์ Tomato 1 		มีภาพอยู่ 738
# ภาพในโฟลเดอร์ Tomato 2 		มีภาพอยู่ 672
# ภาพในโฟลเดอร์ Tomato Cherry Red 		มีภาพอยู่ 492
# ภาพในโฟลเดอร์ Tomato Yellow 		มีภาพอยู่ 459
# ภาพในโฟลเดอร์ Tomato 3 		มีภาพอยู่ 738
# ภาพในโฟลเดอร์ Tomato Maroon 		มีภาพอยู่ 367
# ----------------
# มีภาพ Tomato/ ทั้งหมด 4726 ภาพ
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FF5EABEFF10>
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FF5EABEFE10>
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FF5EABEF790>

# %% [markdown]
# ## Split - Train data and validation data

# %% [markdown]
# - เตรียม library ต่างๆที่จำเป็น ต้องใช้ในการ Train model

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# - กำหนด shape ของภาพเป็น 224x224

# %%
height = 224
width = 224
batch_size = 32
data_dir = '/content/train'

# %% [markdown]
# - ดึงข้อมูลจาก path data_dir ซึ่งคือ โฟลเดอร์ Train เพื่อทำการแบ่งเป็น  training set 70 % และ validation set อยู่ 30 %

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    validation_split = 0.3,
    subset = 'training',
    seed = 123,
    image_size = (height, width),
    batch_size = batch_size
)
# Out:
# Found 11219 files belonging to 3 classes.
# Using 7854 files for training.

# %% [markdown]
# - ดึงข้อมูลจาก path data_dir ซึ่งคือ โฟลเดอร์ Train เพื่อทำการแบ่งเป็น validation set

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    validation_split = 0.3,
    subset = 'validation',
    seed = 123,
    image_size = (height, width),
    batch_size = batch_size
)
# Out:
# Found 11219 files belonging to 3 classes.
# Using 3365 files for validation.

# %% [markdown]
# - เช็คดู class_names

# %%
classes = train_ds.class_names
print(classes)
print(train_ds)
# Out:
# ['Apple', 'Banana', 'Tomato']
# <BatchDataset shapes: ((None, 224, 224, 3), (None,)), types: (tf.float32, tf.int32)>

# %% [markdown]
# ## Training The Model

# %% [markdown]
# ### MobileNetv2

# %% [markdown]
# - Document - MobileNetv2 model
# - https://keras.io/api/applications/mobilenet/

# %% [markdown]
# - Load Model

# %%
from tensorflow.keras.applications import MobileNetV2
model = MobileNetV2(weights = 'imagenet')

# %%
model.compile(optimizer='adam',
              loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics = ['accuracy'])

# %%
model.summary()
# Out:
# Model: "mobilenetv2_1.00_224"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 112, 112, 32) 864         input_2[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 112, 112, 32) 128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 112, 112, 32) 0           bn_Conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 112, 112, 32) 288         Conv1_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_BN (Bat (None, 112, 112, 32) 128         expanded_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_relu (R (None, 112, 112, 32) 0           expanded_conv_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project (Conv2D)  (None, 112, 112, 16) 512         expanded_conv_depthwise_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_project_BN (Batch (None, 112, 112, 16) 64          expanded_conv_project[0][0]
# __________________________________________________________________________________________________
# block_1_expand (Conv2D)         (None, 112, 112, 96) 1536        expanded_conv_project_BN[0][0]
# __________________________________________________________________________________________________
# block_1_expand_BN (BatchNormali (None, 112, 112, 96) 384         block_1_expand[0][0]
# __________________________________________________________________________________________________
# block_1_expand_relu (ReLU)      (None, 112, 112, 96) 0           block_1_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_1_pad (ZeroPadding2D)     (None, 113, 113, 96) 0           block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise (DepthwiseCon (None, 56, 56, 96)   864         block_1_pad[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_BN (BatchNorm (None, 56, 56, 96)   384         block_1_depthwise[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_relu (ReLU)   (None, 56, 56, 96)   0           block_1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_1_project (Conv2D)        (None, 56, 56, 24)   2304        block_1_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_1_project_BN (BatchNormal (None, 56, 56, 24)   96          block_1_project[0][0]
# __________________________________________________________________________________________________
# block_2_expand (Conv2D)         (None, 56, 56, 144)  3456        block_1_project_BN[0][0]
# __________________________________________________________________________________________________
# block_2_expand_BN (BatchNormali (None, 56, 56, 144)  576         block_2_expand[0][0]
# __________________________________________________________________________________________________
# block_2_expand_relu (ReLU)      (None, 56, 56, 144)  0           block_2_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise (DepthwiseCon (None, 56, 56, 144)  1296        block_2_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_BN (BatchNorm (None, 56, 56, 144)  576         block_2_depthwise[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_relu (ReLU)   (None, 56, 56, 144)  0           block_2_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_2_project (Conv2D)        (None, 56, 56, 24)   3456        block_2_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_2_project_BN (BatchNormal (None, 56, 56, 24)   96          block_2_project[0][0]
# __________________________________________________________________________________________________
# block_2_add (Add)               (None, 56, 56, 24)   0           block_1_project_BN[0][0]
#                                                                  block_2_project_BN[0][0]
# __________________________________________________________________________________________________
# block_3_expand (Conv2D)         (None, 56, 56, 144)  3456        block_2_add[0][0]
# __________________________________________________________________________________________________
# block_3_expand_BN (BatchNormali (None, 56, 56, 144)  576         block_3_expand[0][0]
# __________________________________________________________________________________________________
# block_3_expand_relu (ReLU)      (None, 56, 56, 144)  0           block_3_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_3_pad (ZeroPadding2D)     (None, 57, 57, 144)  0           block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise (DepthwiseCon (None, 28, 28, 144)  1296        block_3_pad[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_BN (BatchNorm (None, 28, 28, 144)  576         block_3_depthwise[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_relu (ReLU)   (None, 28, 28, 144)  0           block_3_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_3_project (Conv2D)        (None, 28, 28, 32)   4608        block_3_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_3_project_BN (BatchNormal (None, 28, 28, 32)   128         block_3_project[0][0]
# __________________________________________________________________________________________________
# block_4_expand (Conv2D)         (None, 28, 28, 192)  6144        block_3_project_BN[0][0]
# __________________________________________________________________________________________________
# block_4_expand_BN (BatchNormali (None, 28, 28, 192)  768         block_4_expand[0][0]
# __________________________________________________________________________________________________
# block_4_expand_relu (ReLU)      (None, 28, 28, 192)  0           block_4_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise (DepthwiseCon (None, 28, 28, 192)  1728        block_4_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_BN (BatchNorm (None, 28, 28, 192)  768         block_4_depthwise[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_relu (ReLU)   (None, 28, 28, 192)  0           block_4_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_4_project (Conv2D)        (None, 28, 28, 32)   6144        block_4_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_4_project_BN (BatchNormal (None, 28, 28, 32)   128         block_4_project[0][0]
# __________________________________________________________________________________________________
# block_4_add (Add)               (None, 28, 28, 32)   0           block_3_project_BN[0][0]
#                                                                  block_4_project_BN[0][0]
# __________________________________________________________________________________________________
# block_5_expand (Conv2D)         (None, 28, 28, 192)  6144        block_4_add[0][0]
# __________________________________________________________________________________________________
# block_5_expand_BN (BatchNormali (None, 28, 28, 192)  768         block_5_expand[0][0]
# __________________________________________________________________________________________________
# block_5_expand_relu (ReLU)      (None, 28, 28, 192)  0           block_5_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise (DepthwiseCon (None, 28, 28, 192)  1728        block_5_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_BN (BatchNorm (None, 28, 28, 192)  768         block_5_depthwise[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_relu (ReLU)   (None, 28, 28, 192)  0           block_5_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_5_project (Conv2D)        (None, 28, 28, 32)   6144        block_5_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_5_project_BN (BatchNormal (None, 28, 28, 32)   128         block_5_project[0][0]
# __________________________________________________________________________________________________
# block_5_add (Add)               (None, 28, 28, 32)   0           block_4_add[0][0]
#                                                                  block_5_project_BN[0][0]
# __________________________________________________________________________________________________
# block_6_expand (Conv2D)         (None, 28, 28, 192)  6144        block_5_add[0][0]
# __________________________________________________________________________________________________
# block_6_expand_BN (BatchNormali (None, 28, 28, 192)  768         block_6_expand[0][0]
# __________________________________________________________________________________________________
# block_6_expand_relu (ReLU)      (None, 28, 28, 192)  0           block_6_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_6_pad (ZeroPadding2D)     (None, 29, 29, 192)  0           block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise (DepthwiseCon (None, 14, 14, 192)  1728        block_6_pad[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_BN (BatchNorm (None, 14, 14, 192)  768         block_6_depthwise[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_relu (ReLU)   (None, 14, 14, 192)  0           block_6_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_6_project (Conv2D)        (None, 14, 14, 64)   12288       block_6_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_6_project_BN (BatchNormal (None, 14, 14, 64)   256         block_6_project[0][0]
# __________________________________________________________________________________________________
# block_7_expand (Conv2D)         (None, 14, 14, 384)  24576       block_6_project_BN[0][0]
# __________________________________________________________________________________________________
# block_7_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_7_expand[0][0]
# __________________________________________________________________________________________________
# block_7_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_7_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_7_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_7_depthwise[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_7_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_7_project (Conv2D)        (None, 14, 14, 64)   24576       block_7_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_7_project_BN (BatchNormal (None, 14, 14, 64)   256         block_7_project[0][0]
# __________________________________________________________________________________________________
# block_7_add (Add)               (None, 14, 14, 64)   0           block_6_project_BN[0][0]
#                                                                  block_7_project_BN[0][0]
# __________________________________________________________________________________________________
# block_8_expand (Conv2D)         (None, 14, 14, 384)  24576       block_7_add[0][0]
# __________________________________________________________________________________________________
# block_8_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_8_expand[0][0]
# __________________________________________________________________________________________________
# block_8_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_8_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_8_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_8_depthwise[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_8_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_8_project (Conv2D)        (None, 14, 14, 64)   24576       block_8_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_8_project_BN (BatchNormal (None, 14, 14, 64)   256         block_8_project[0][0]
# __________________________________________________________________________________________________
# block_8_add (Add)               (None, 14, 14, 64)   0           block_7_add[0][0]
#                                                                  block_8_project_BN[0][0]
# __________________________________________________________________________________________________
# block_9_expand (Conv2D)         (None, 14, 14, 384)  24576       block_8_add[0][0]
# __________________________________________________________________________________________________
# block_9_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_9_expand[0][0]
# __________________________________________________________________________________________________
# block_9_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_9_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_9_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_9_depthwise[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_9_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_9_project (Conv2D)        (None, 14, 14, 64)   24576       block_9_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_9_project_BN (BatchNormal (None, 14, 14, 64)   256         block_9_project[0][0]
# __________________________________________________________________________________________________
# block_9_add (Add)               (None, 14, 14, 64)   0           block_8_add[0][0]
#                                                                  block_9_project_BN[0][0]
# __________________________________________________________________________________________________
# block_10_expand (Conv2D)        (None, 14, 14, 384)  24576       block_9_add[0][0]
# __________________________________________________________________________________________________
# block_10_expand_BN (BatchNormal (None, 14, 14, 384)  1536        block_10_expand[0][0]
# __________________________________________________________________________________________________
# block_10_expand_relu (ReLU)     (None, 14, 14, 384)  0           block_10_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise (DepthwiseCo (None, 14, 14, 384)  3456        block_10_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_BN (BatchNor (None, 14, 14, 384)  1536        block_10_depthwise[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           block_10_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_10_project (Conv2D)       (None, 14, 14, 96)   36864       block_10_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_10_project_BN (BatchNorma (None, 14, 14, 96)   384         block_10_project[0][0]
# __________________________________________________________________________________________________
# block_11_expand (Conv2D)        (None, 14, 14, 576)  55296       block_10_project_BN[0][0]
# __________________________________________________________________________________________________
# block_11_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_11_expand[0][0]
# __________________________________________________________________________________________________
# block_11_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_11_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise (DepthwiseCo (None, 14, 14, 576)  5184        block_11_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_BN (BatchNor (None, 14, 14, 576)  2304        block_11_depthwise[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_relu (ReLU)  (None, 14, 14, 576)  0           block_11_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_11_project (Conv2D)       (None, 14, 14, 96)   55296       block_11_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_11_project_BN (BatchNorma (None, 14, 14, 96)   384         block_11_project[0][0]
# __________________________________________________________________________________________________
# block_11_add (Add)              (None, 14, 14, 96)   0           block_10_project_BN[0][0]
#                                                                  block_11_project_BN[0][0]
# __________________________________________________________________________________________________
# block_12_expand (Conv2D)        (None, 14, 14, 576)  55296       block_11_add[0][0]
# __________________________________________________________________________________________________
# block_12_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_12_expand[0][0]
# __________________________________________________________________________________________________
# block_12_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_12_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise (DepthwiseCo (None, 14, 14, 576)  5184        block_12_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_BN (BatchNor (None, 14, 14, 576)  2304        block_12_depthwise[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_relu (ReLU)  (None, 14, 14, 576)  0           block_12_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_12_project (Conv2D)       (None, 14, 14, 96)   55296       block_12_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_12_project_BN (BatchNorma (None, 14, 14, 96)   384         block_12_project[0][0]
# __________________________________________________________________________________________________
# block_12_add (Add)              (None, 14, 14, 96)   0           block_11_add[0][0]
#                                                                  block_12_project_BN[0][0]
# __________________________________________________________________________________________________
# block_13_expand (Conv2D)        (None, 14, 14, 576)  55296       block_12_add[0][0]
# __________________________________________________________________________________________________
# block_13_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_13_expand[0][0]
# __________________________________________________________________________________________________
# block_13_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_13_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_13_pad (ZeroPadding2D)    (None, 15, 15, 576)  0           block_13_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise (DepthwiseCo (None, 7, 7, 576)    5184        block_13_pad[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_BN (BatchNor (None, 7, 7, 576)    2304        block_13_depthwise[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_relu (ReLU)  (None, 7, 7, 576)    0           block_13_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_13_project (Conv2D)       (None, 7, 7, 160)    92160       block_13_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_13_project_BN (BatchNorma (None, 7, 7, 160)    640         block_13_project[0][0]
# __________________________________________________________________________________________________
# block_14_expand (Conv2D)        (None, 7, 7, 960)    153600      block_13_project_BN[0][0]
# __________________________________________________________________________________________________
# block_14_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_14_expand[0][0]
# __________________________________________________________________________________________________
# block_14_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_14_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_14_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_14_depthwise[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_14_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_14_project (Conv2D)       (None, 7, 7, 160)    153600      block_14_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_14_project_BN (BatchNorma (None, 7, 7, 160)    640         block_14_project[0][0]
# __________________________________________________________________________________________________
# block_14_add (Add)              (None, 7, 7, 160)    0           block_13_project_BN[0][0]
#                                                                  block_14_project_BN[0][0]
# __________________________________________________________________________________________________
# block_15_expand (Conv2D)        (None, 7, 7, 960)    153600      block_14_add[0][0]
# __________________________________________________________________________________________________
# block_15_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_15_expand[0][0]
# __________________________________________________________________________________________________
# block_15_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_15_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_15_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_15_depthwise[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_15_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_15_project (Conv2D)       (None, 7, 7, 160)    153600      block_15_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_15_project_BN (BatchNorma (None, 7, 7, 160)    640         block_15_project[0][0]
# __________________________________________________________________________________________________
# block_15_add (Add)              (None, 7, 7, 160)    0           block_14_add[0][0]
#                                                                  block_15_project_BN[0][0]
# __________________________________________________________________________________________________
# block_16_expand (Conv2D)        (None, 7, 7, 960)    153600      block_15_add[0][0]
# __________________________________________________________________________________________________
# block_16_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_16_expand[0][0]
# __________________________________________________________________________________________________
# block_16_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_16_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_16_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_16_depthwise[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_16_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_16_project (Conv2D)       (None, 7, 7, 320)    307200      block_16_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_16_project_BN (BatchNorma (None, 7, 7, 320)    1280        block_16_project[0][0]
# __________________________________________________________________________________________________
# Conv_1 (Conv2D)                 (None, 7, 7, 1280)   409600      block_16_project_BN[0][0]
# __________________________________________________________________________________________________
# Conv_1_bn (BatchNormalization)  (None, 7, 7, 1280)   5120        Conv_1[0][0]
# __________________________________________________________________________________________________
# out_relu (ReLU)                 (None, 7, 7, 1280)   0           Conv_1_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 1280)         0           out_relu[0][0]
# __________________________________________________________________________________________________
# predictions (Dense)             (None, 1000)         1281000     global_average_pooling2d_1[0][0]
# ==================================================================================================
# Total params: 3,538,984
# Trainable params: 3,504,872
# Non-trainable params: 34,112
# __________________________________________________________________________________________________

# %% [markdown]
# ### Train
# https://keras.rstudio.com/reference/fit.html#arguments
#
# validation_data
# Data on which to evaluate the loss and any model metrics at the end of each epoch. The model will not be trained on this data. This could be a list (x_val, y_val) or a list (x_val, y_val, val_sample_weights). validation_data will override validation_split.
#
#
# - หมายถึง ข้อมูลการตรวจสอบ ประเมินค่า loss และ model metrics เมื่อจบ epoch
#
#
# epochs
# Number of epochs to train the model. Note that in conjunction with initial_epoch, epochs is to be understood as "final epoch". The model is not trained for a number of iterations given by epochs, but merely until the epoch of index epochs is reached.
#
# - epochs	คือ จำนวนครั้งในการฝึกโมเดล

# %%
epochs = 50
ABTFruit = model.fit(train_ds,
                     validation_data=val_ds, 
                     epochs=epochs
                     )
# Out:
# Epoch 1/50
# 246/246 [==============================] - 96s 388ms/step - loss: 0.0040 - accuracy: 0.9990 - val_loss: 0.7243 - val_accuracy: 0.9290
# Epoch 2/50
# 246/246 [==============================] - 96s 389ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.0543 - val_accuracy: 0.9955
# Epoch 3/50
# 246/246 [==============================] - 96s 389ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0329 - val_accuracy: 0.9979
# Epoch 4/50
# 246/246 [==============================] - 96s 387ms/step - loss: 1.1574e-04 - accuracy: 1.0000 - val_loss: 0.0317 - val_accuracy: 0.9979
# Epoch 5/50
# 246/246 [==============================] - 96s 388ms/step - loss: 5.0166e-04 - accuracy: 0.9999 - val_loss: 0.0274 - val_accuracy: 0.9976
# Epoch 6/50
# 246/246 [==============================] - 96s 387ms/step - loss: 0.0340 - accuracy: 0.9916 - val_loss: 17.5457 - val_accuracy: 0.4716
# Epoch 7/50
# 246/246 [==============================] - 95s 386ms/step - loss: 0.0141 - accuracy: 0.9955 - val_loss: 13.6271 - val_accuracy: 0.5376
# Epoch 8/50
# 246/246 [==============================] - 95s 385ms/step - loss: 0.0145 - accuracy: 0.9952 - val_loss: 2.1025 - val_accuracy: 0.8202
# Epoch 9/50
# 246/246 [==============================] - 96s 387ms/step - loss: 0.0070 - accuracy: 0.9977 - val_loss: 0.3633 - val_accuracy: 0.9483
# Epoch 10/50
# 246/246 [==============================] - 96s 387ms/step - loss: 0.0102 - accuracy: 0.9982 - val_loss: 15.0667 - val_accuracy: 0.4657
# Epoch 11/50
# 246/246 [==============================] - 96s 388ms/step - loss: 0.0112 - accuracy: 0.9971 - val_loss: 5.4735 - val_accuracy: 0.5233
# Epoch 12/50
# 246/246 [==============================] - 96s 388ms/step - loss: 0.0072 - accuracy: 0.9980 - val_loss: 2.8463 - val_accuracy: 0.8205
# Epoch 13/50
# 246/246 [==============================] - 96s 387ms/step - loss: 0.0051 - accuracy: 0.9982 - val_loss: 3.3308 - val_accuracy: 0.7325
# Epoch 14/50
# 246/246 [==============================] - 96s 388ms/step - loss: 5.9541e-04 - accuracy: 0.9999 - val_loss: 0.1699 - val_accuracy: 0.9935
# Epoch 15/50
# 246/246 [==============================] - 96s 387ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.1666 - val_accuracy: 0.9848
# Epoch 16/50
# 246/246 [==============================] - 95s 386ms/step - loss: 0.0040 - accuracy: 0.9986 - val_loss: 0.0644 - val_accuracy: 0.9961
# Epoch 17/50
# 246/246 [==============================] - 96s 388ms/step - loss: 0.0067 - accuracy: 0.9986 - val_loss: 1.5187 - val_accuracy: 0.8520
# Epoch 18/50
# 246/246 [==============================] - 95s 386ms/step - loss: 0.0140 - accuracy: 0.9955 - val_loss: 1.0346 - val_accuracy: 0.9007
# Epoch 19/50
# 246/246 [==============================] - 95s 386ms/step - loss: 0.0055 - accuracy: 0.9981 - val_loss: 0.3005 - val_accuracy: 0.9762
# Epoch 20/50
# 246/246 [==============================] - 96s 388ms/step - loss: 0.0047 - accuracy: 0.9981 - val_loss: 0.1617 - val_accuracy: 0.9718
# Epoch 21/50
# 246/246 [==============================] - 96s 388ms/step - loss: 0.0029 - accuracy: 0.9994 - val_loss: 0.0926 - val_accuracy: 0.9961
# Epoch 22/50
# 246/246 [==============================] - 96s 388ms/step - loss: 0.0083 - accuracy: 0.9976 - val_loss: 0.2288 - val_accuracy: 0.9608
# Epoch 23/50
# 246/246 [==============================] - 96s 389ms/step - loss: 0.0027 - accuracy: 0.9991 - val_loss: 0.3386 - val_accuracy: 0.9456
# Epoch 24/50
# 246/246 [==============================] - 96s 388ms/step - loss: 9.3359e-04 - accuracy: 0.9999 - val_loss: 0.0936 - val_accuracy: 0.9840
# Epoch 25/50
# 246/246 [==============================] - 96s 388ms/step - loss: 0.0087 - accuracy: 0.9982 - val_loss: 0.3089 - val_accuracy: 0.9640
# Epoch 26/50
# 246/246 [==============================] - 96s 387ms/step - loss: 0.0089 - accuracy: 0.9972 - val_loss: 0.3161 - val_accuracy: 0.9851
# Epoch 27/50
# 246/246 [==============================] - 96s 388ms/step - loss: 0.0054 - accuracy: 0.9983 - val_loss: 2.2085 - val_accuracy: 0.7804
# Epoch 28/50
# 246/246 [==============================] - 96s 388ms/step - loss: 0.0087 - accuracy: 0.9981 - val_loss: 1.6637 - val_accuracy: 0.8226
# Epoch 29/50
# 246/246 [==============================] - 96s 389ms/step - loss: 0.0045 - accuracy: 0.9982 - val_loss: 13.6841 - val_accuracy: 0.6098
# Epoch 30/50
# 246/246 [==============================] - 96s 389ms/step - loss: 0.0012 - accuracy: 0.9995 - val_loss: 10.1923 - val_accuracy: 0.6779
# Epoch 31/50
# 246/246 [==============================] - 96s 389ms/step - loss: 6.6009e-04 - accuracy: 0.9997 - val_loss: 0.1863 - val_accuracy: 0.9881
# Epoch 32/50
# 246/246 [==============================] - 96s 388ms/step - loss: 2.4421e-04 - accuracy: 0.9999 - val_loss: 0.1344 - val_accuracy: 0.9816
# Epoch 33/50
# 246/246 [==============================] - 96s 389ms/step - loss: 0.0132 - accuracy: 0.9967 - val_loss: 0.0646 - val_accuracy: 0.9941
# Epoch 34/50
# 246/246 [==============================] - 96s 390ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.0385 - val_accuracy: 0.9967
# Epoch 35/50
# 246/246 [==============================] - 97s 390ms/step - loss: 2.0404e-04 - accuracy: 1.0000 - val_loss: 0.0310 - val_accuracy: 0.9976
# Epoch 36/50
# 246/246 [==============================] - 97s 391ms/step - loss: 0.0076 - accuracy: 0.9985 - val_loss: 0.0325 - val_accuracy: 0.9961
# Epoch 37/50
# 246/246 [==============================] - 97s 392ms/step - loss: 0.0039 - accuracy: 0.9987 - val_loss: 2.4992 - val_accuracy: 0.7676
# Epoch 38/50
# 246/246 [==============================] - 97s 391ms/step - loss: 6.2120e-04 - accuracy: 0.9996 - val_loss: 0.1232 - val_accuracy: 0.9718
# Epoch 39/50
# 246/246 [==============================] - 96s 390ms/step - loss: 1.7693e-04 - accuracy: 1.0000 - val_loss: 0.0203 - val_accuracy: 0.9979
# Epoch 40/50
# 246/246 [==============================] - 97s 390ms/step - loss: 3.2016e-05 - accuracy: 1.0000 - val_loss: 0.0197 - val_accuracy: 0.9982
# Epoch 41/50
# 246/246 [==============================] - 97s 392ms/step - loss: 1.5815e-05 - accuracy: 1.0000 - val_loss: 0.0200 - val_accuracy: 0.9979
# Epoch 42/50
# 246/246 [==============================] - 97s 392ms/step - loss: 2.0727e-05 - accuracy: 1.0000 - val_loss: 0.0195 - val_accuracy: 0.9973
# Epoch 43/50
# 246/246 [==============================] - 97s 391ms/step - loss: 9.6773e-06 - accuracy: 1.0000 - val_loss: 0.0192 - val_accuracy: 0.9976
# Epoch 44/50
# 246/246 [==============================] - 97s 391ms/step - loss: 3.9716e-05 - accuracy: 1.0000 - val_loss: 0.0196 - val_accuracy: 0.9973
# Epoch 45/50
# 246/246 [==============================] - 97s 391ms/step - loss: 0.0084 - accuracy: 0.9981 - val_loss: 0.9806 - val_accuracy: 0.8963
# Epoch 46/50
# 246/246 [==============================] - 97s 391ms/step - loss: 0.0033 - accuracy: 0.9994 - val_loss: 1.0408 - val_accuracy: 0.9040
# Epoch 47/50
# 246/246 [==============================] - 97s 391ms/step - loss: 8.6810e-04 - accuracy: 0.9997 - val_loss: 0.2881 - val_accuracy: 0.9655
# Epoch 48/50
# 246/246 [==============================] - 97s 392ms/step - loss: 0.0158 - accuracy: 0.9958 - val_loss: 6.5452 - val_accuracy: 0.6612
# Epoch 49/50
# 246/246 [==============================] - 97s 391ms/step - loss: 0.0063 - accuracy: 0.9982 - val_loss: 1.8295 - val_accuracy: 0.8799
# Epoch 50/50
# 246/246 [==============================] - 97s 391ms/step - loss: 3.4007e-04 - accuracy: 1.0000 - val_loss: 0.1189 - val_accuracy: 0.9932

# %% [markdown]
# ## Evaluation

# %%
# plot the training loss and accuracy
N = 50
plt.style.use("ggplot")
plt.figure()

plt.plot(np.arange(0, N), ABTFruit.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), ABTFruit.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), ABTFruit.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), ABTFruit.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
# plt.savefig(args["plot"])

# %% [markdown]
# - Evaluation model ทำการพล็อตกราฟดูค่าความถูกต้องและค่าความผิดพลาด acc/loss

# %%
# Model Accuracy
fig1 = plt.gcf()

plt.plot(ABTFruit.history['accuracy'])
plt.plot(ABTFruit.history['val_accuracy'])
plt.axis(ymin=0.3, ymax=1)
plt.grid()
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'validation'])
plt.show()

# %%
# Model Loss
plt.plot(ABTFruit.history['loss'])
plt.plot(ABTFruit.history['val_loss'])
plt.grid()
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'validation'])
plt.show()

# %% [markdown]
# ## Prediction

# %% [markdown]
# - ทำการนำโมลที่เทรนได้มาใช้ มาทำนายจากภาพ โดยใช้การอัพโหลดภาพ

# %%
def pred_func(image):
  """
  arg = image
  
  return :
  output_class : result class name
  pred : 
  """
  img = cv2.resize(image, (224, 224), interpolation=cv2.INTER_AREA)
  img = np.expand_dims(img, axis=0)
  # print(img.shape)
  pred = model.predict(img)
  prediction = np.argmax(pred, axis=1)
  print(prediction)
  output_class = np.argmax(pred)
  return output_class, pred

# %%
import os
import cv2 as cv
# ฟังก์ชันสำหรับโหลดภาพเข้ามา
def load_images_from_folder(folder):
    images = [] # สร้าง list สำหรับเก็บภาพ 
    for filename in os.listdir(folder): # ลูปดูภาพใน folder 
        img = cv.imread(os.path.join(folder,filename))  # ทำการอ่านภาพจาก ชื่อภาพ โดย cv.imread เก็บไว้ img 
        if img is not None: # เช็คดูว่าถ้าไม่ได้เป็นค่าว่าง 
            images.append(img) # ให้เก็บไว้ใน list images
    return images # คืนค่าเป็น list Images

# %%
apple_test = '/content/test/Apple'
banana_test = '/content/test/Banana'
tomato_test = '/content/test/Tomato'

apple_image = load_images_from_folder(apple_test)
banana_image = load_images_from_folder(banana_test)
tomato_image = load_images_from_folder(tomato_test)
print(len(apple_image))
print(len(banana_image))
print(len(tomato_image))
# Out:
# 7
# 8
# 10

# %%
import cv2
for img in apple_image:
  scale_percent = 10 # percent of original size
  width = int(img.shape[1] * scale_percent / 100)
  height = int(img.shape[0] * scale_percent / 100)
  dim = (width, height)
  # resize image
  resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)



  output, pred = pred_func(resized)

  cv2_imshow(resized)
  print("-------------------------------------", classes[np.argmax(pred)])
# Out:
# [0]
# <PIL.Image.Image image mode=RGB size=221x221 at 0x7FF573C76310>
# ------------------------------------- Apple
# [1]
# <PIL.Image.Image image mode=RGB size=118x81 at 0x7FF573CE6550>
# ------------------------------------- Banana
# [0]
# <PIL.Image.Image image mode=RGB size=221x221 at 0x7FF573CFAB90>
# ------------------------------------- Apple
# [0]
# <PIL.Image.Image image mode=RGB size=120x160 at 0x7FF573C971D0>
# ------------------------------------- Apple
# [1]
# <PIL.Image.Image image mode=RGB size=200x100 at 0x7FF573CFA210>
# ------------------------------------- Banana
# [1]
# <PIL.Image.Image image mode=RGB size=102x68 at 0x7FF573B97C90>
# ------------------------------------- Banana
# [0]
# <PIL.Image.Image image mode=RGB size=128x72 at 0x7FF573B97210>
# ------------------------------------- Apple

# %%
for img in banana_image:
  scale_percent = 10 # percent of original size
  width = int(img.shape[1] * scale_percent / 100)
  height = int(img.shape[0] * scale_percent / 100)
  dim = (width, height)
  # resize image
  resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)

  output, pred = pred_func(img)

  cv2_imshow(resized)
  print("-------------------------------------", classes[np.argmax(pred)])
# Out:
# [0]
# <PIL.Image.Image image mode=RGB size=120x80 at 0x7FF573B64E90>
# ------------------------------------- Apple
# [1]
# <PIL.Image.Image image mode=RGB size=120x79 at 0x7FF573B52810>
# ------------------------------------- Banana
# [0]
# <PIL.Image.Image image mode=RGB size=85x47 at 0x7FF573B52310>
# ------------------------------------- Apple
# [0]
# <PIL.Image.Image image mode=RGB size=128x72 at 0x7FF573B521D0>
# ------------------------------------- Apple
# [0]
# <PIL.Image.Image image mode=RGB size=128x72 at 0x7FF573B52150>
# ------------------------------------- Apple
# [0]
# <PIL.Image.Image image mode=RGB size=120x80 at 0x7FF573B5F650>
# ------------------------------------- Apple
# [0]
# <PIL.Image.Image image mode=RGB size=120x105 at 0x7FF573C85790>
# ------------------------------------- Apple
# [1]
# <PIL.Image.Image image mode=RGB size=48x36 at 0x7FF573B7DA90>
# ------------------------------------- Banana

# %%
for img in tomato_image:
  scale_percent = 10 # percent of original size
  width = int(img.shape[1] * scale_percent / 100)
  height = int(img.shape[0] * scale_percent / 100)
  dim = (width, height)
  # resize image
  resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)

  output, pred = pred_func(img)

  cv2_imshow(resized)
  print("-------------------------------------", classes[np.argmax(pred)])
# Out:
# <PIL.Image.Image image mode=RGB size=160x106 at 0x7FF573FA8510>
# ------------------------------------- Tomato
# <PIL.Image.Image image mode=RGB size=240x180 at 0x7FF572067F50>
# ------------------------------------- Tomato
# <PIL.Image.Image image mode=RGB size=335x238 at 0x7FF573FA8510>
# ------------------------------------- Banana
# <PIL.Image.Image image mode=RGB size=160x106 at 0x7FF573FE8ED0>
# ------------------------------------- Tomato
# <PIL.Image.Image image mode=RGB size=120x160 at 0x7FF574002890>
# ------------------------------------- Tomato
# <PIL.Image.Image image mode=RGB size=160x106 at 0x7FF57404AC90>
# ------------------------------------- Tomato
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7FF57406B550>
# ------------------------------------- Apple
# <PIL.Image.Image image mode=RGB size=180x120 at 0x7FF573F0D9D0>
# ------------------------------------- Apple
# <PIL.Image.Image image mode=RGB size=102x112 at 0x7FF574028110>
# ------------------------------------- Banana
# <PIL.Image.Image image mode=RGB size=80x120 at 0x7FF574028190>
# ------------------------------------- Banana

# %%
# for upload image
# from google.colab import files
# from google.colab.patches import cv2_imshow
# import cv2

# uploaded = files.upload()


# print(uploaded.keys())
# print("ภาพที่อัพโหลดขึ้นมาคือ", list(uploaded)[0])
# upload_img = list(uploaded)[0]
# image = cv2.imread(upload_img)
# # print(image)
# cv2_imshow(image)

# # ---------------------------------
# output, pred = pred_func(image)
# if output == 0:
#   print("Apple")
# elif output == 1:
#   print("Banana")
# elif output == 2:
#   print("Tomato")
# else:
#   pass

# %% [markdown]
# ## Deploy Model

# %% [markdown]
# - ทำการ save model เป็นไฟล์ โมเดล .h5

# %%
model.save('abtmodel', save_format='h5')
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
